# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('data/startup-expansion.xlsx')
df
# Out:
#      Store ID             City       State Sales Region New Expansion  \
# 0           1           Peoria     Arizona     Region 2           Old
# 1           2          Midland       Texas     Region 2           Old
# 2           3          Spokane  Washington     Region 2           Old
# 3           4           Denton       Texas     Region 2           Old
# 4           5    Overland Park      Kansas     Region 2           Old
# ..        ...              ...         ...          ...           ...
# 145       146         Paterson  New Jersey     Region 1           New
# 146       147      Brownsville       Texas     Region 2           New
# 147       148         Rockford    Illinois     Region 1           New
# 148       149  College Station       Texas     Region 2           New
# 149       150    Thousand Oaks  California     Region 2           New
#
#      Marketing Spend  Revenue
# 0               2601    48610
# 1               2727    45689
# 2               2768    49554
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Store ID         150 non-null    int64
#  1   City             150 non-null    object
#  2   State            150 non-null    object
#  3   Sales Region     150 non-null    object
#  4   New Expansion    150 non-null    object
#  5   Marketing Spend  150 non-null    int64
#  6   Revenue          150 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 8.3+ KB

# %%
df.describe()
# Out:
#          Store ID  Marketing Spend       Revenue
# count  150.000000       150.000000    150.000000
# mean    75.500000      2893.146667  39301.433333
# std     43.445368       367.862817  15465.753977
# min      1.000000      1811.000000  15562.000000
# 25%     38.250000      2662.250000  21113.500000
# 50%     75.500000      2898.000000  42993.000000
# 75%    112.750000      3111.500000  51145.500000
# max    150.000000      3984.000000  68828.000000

# %%
df.describe().round(2)
# Out:
#        Store ID  Marketing Spend   Revenue
# count    150.00           150.00    150.00
# mean      75.50          2893.15  39301.43
# std       43.45           367.86  15465.75
# min        1.00          1811.00  15562.00
# 25%       38.25          2662.25  21113.50
# 50%       75.50          2898.00  42993.00
# 75%      112.75          3111.50  51145.50
# max      150.00          3984.00  68828.00

# %%
df[['Marketing Spend','Revenue']].describe().round(2)
# Out:
#        Marketing Spend   Revenue
# count           150.00    150.00
# mean           2893.15  39301.43
# std             367.86  15465.75
# min            1811.00  15562.00
# 25%            2662.25  21113.50
# 50%            2898.00  42993.00
# 75%            3111.50  51145.50
# max            3984.00  68828.00

# %%
df['City'].nunique()
# Out:
# 149

# %%
df['City'].unique()
# Out:
# array(['Peoria', 'Midland', 'Spokane', 'Denton', 'Overland Park',
#        'Yonkers', 'Birmingham', 'Antioch', 'Worcester', 'Rochester',
#        'Rialto', 'Santa Maria', 'Las Cruces', 'Jackson', 'Hillsboro',
#        'Temecula', 'Tallahassee', 'Fontana', 'Kent', 'Broken Arrow',
#        'Concord', 'Modesto', 'Montgomery', 'Burbank', 'Elk Grove',
#        'Port St. Lucie', 'Elizabeth', 'Salt Lake City', 'Waco', 'Edison',
#        'Boulder', 'Grand Rapids', 'Tyler', 'Charleston', 'Huntsville',
#        'Pearland', 'Inglewood', 'Oxnard', 'Miramar', 'Cape Coral',
#        'Syracuse', 'Newport News', 'Lewisville', 'Carrollton',
#        'San Bernardino', 'Pasadena', 'Roseville', 'Murrieta',
#        'San Angelo', 'Olathe', 'Akron', 'Fullerton', 'Manchester',
#        'Everett', 'West Covina', 'Thornton', 'Hampton', 'Waterbury',
#        'Ventura', 'Davenport', 'Columbia', 'Simi Valley', 'Richmond',
#        'Little Rock', 'El Cajon', 'Santa Clara', 'Oceanside', 'Davie',
# ...

# %%
df['City'].value_counts()
# Out:
# City
# Rochester        2
# Killeen          1
# Wichita Falls    1
# Naperville       1
# Clovis           1
#                 ..
# Akron            1
# Fullerton        1
# Manchester       1
# Everett          1
# Thousand Oaks    1
# Name: count, Length: 149, dtype: int64

# %%
df['State'].unique()
# Out:
# array(['Arizona', 'Texas', 'Washington', 'Kansas', 'New York', 'Alabama',
#        'California', 'Massachusetts', 'New Mexico', 'Mississippi',
#        'Oregon', 'Florida', 'Oklahoma', 'New Jersey', 'Utah', 'Colorado',
#        'Michigan', 'South Carolina', 'Virginia', 'Ohio', 'New Hampshire',
#        'Connecticut', 'Iowa', 'Arkansas', 'Tennessee', 'North Carolina',
#        'Georgia', 'Illinois', 'Montana', 'Indiana', 'South Dakota',
#        'Louisiana', 'Minnesota', 'Wisconsin', 'Rhode Island'],
#       dtype=object)

# %%
df['State'].nunique()
# Out:
# 35

# %%
df['State'].value_counts()
# Out:
# State
# California        40
# Texas             17
# Florida           12
# Washington         7
# Colorado           5
# Illinois           5
# Georgia            4
# Alabama            4
# Connecticut        4
# New Jersey         4
# Arizona            3
# Tennessee          3
# Iowa               3
# Michigan           3
# South Carolina     3
# Utah               3
# Massachusetts      3
# Kansas             3
# New York           3
# Louisiana          2
# North Carolina     2
# Ohio               2
# Virginia           2
# Oregon             2
# Mississippi        1
# New Mexico         1
# Arkansas           1
# New Hampshire      1
# Oklahoma           1
# Montana            1
# Indiana            1
# South Dakota       1
# Minnesota          1
# Wisconsin          1
# Rhode Island       1
# Name: count, dtype: int64

# %%
len(df['Store ID'].value_counts())
# Out:
# 150

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Length: 150, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull()
# Out:
#      Store ID   City  State  Sales Region  New Expansion  Marketing Spend  \
# 0       False  False  False         False          False            False
# 1       False  False  False         False          False            False
# 2       False  False  False         False          False            False
# 3       False  False  False         False          False            False
# 4       False  False  False         False          False            False
# ..        ...    ...    ...           ...            ...              ...
# 145     False  False  False         False          False            False
# 146     False  False  False         False          False            False
# 147     False  False  False         False          False            False
# 148     False  False  False         False          False            False
# 149     False  False  False         False          False            False
#
#      Revenue
# 0      False
# 1      False
# 2      False
# 3      False
# ...

# %%
df.isna()
# Out:
#      Store ID   City  State  Sales Region  New Expansion  Marketing Spend  \
# 0       False  False  False         False          False            False
# 1       False  False  False         False          False            False
# 2       False  False  False         False          False            False
# 3       False  False  False         False          False            False
# 4       False  False  False         False          False            False
# ..        ...    ...    ...           ...            ...              ...
# 145     False  False  False         False          False            False
# 146     False  False  False         False          False            False
# 147     False  False  False         False          False            False
# 148     False  False  False         False          False            False
# 149     False  False  False         False          False            False
#
#      Revenue
# 0      False
# 1      False
# 2      False
# 3      False
# ...

# %%
df.notna()
# Out:
#      Store ID  City  State  Sales Region  New Expansion  Marketing Spend  \
# 0        True  True   True          True           True             True
# 1        True  True   True          True           True             True
# 2        True  True   True          True           True             True
# 3        True  True   True          True           True             True
# 4        True  True   True          True           True             True
# ..        ...   ...    ...           ...            ...              ...
# 145      True  True   True          True           True             True
# 146      True  True   True          True           True             True
# 147      True  True   True          True           True             True
# 148      True  True   True          True           True             True
# 149      True  True   True          True           True             True
#
#      Revenue
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# ...

# %%
df.sample(10)
# Out:
#      Store ID          City        State Sales Region New Expansion  \
# 144       145      Glendale   California     Region 2           New
# 90         91      Mesquite        Texas     Region 2           Old
# 80         81  Garden Grove   California     Region 2           Old
# 40         41      Syracuse     New York     Region 1           Old
# 48         49    San Angelo        Texas     Region 2           Old
# 68         69      Lakeland      Florida     Region 1           Old
# 64         65      El Cajon   California     Region 2           Old
# 110       111      Stamford  Connecticut     Region 1           Old
# 28         29          Waco        Texas     Region 2           Old
# 135       136     San Mateo   California     Region 2           Old
#
#      Marketing Spend  Revenue
# 144             2363    49376
# 90              3072    40779
# 80              3285    57530
# 40              2373    41313
# 48              2939    50233
# 68              3003    18297
# ...

# %%
df['Sales Region']
# Out:
# 0      Region 2
# 1      Region 2
# 2      Region 2
# 3      Region 2
# 4      Region 2
#          ...
# 145    Region 1
# 146    Region 2
# 147    Region 1
# 148    Region 2
# 149    Region 2
# Name: Sales Region, Length: 150, dtype: object

# %%
df['Sales Region'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sales Region'>

# %%
df.groupby('Store ID')

# %%
df[df['New Expansion'] == 'New']
# Out:
#      Store ID              City       State Sales Region New Expansion  \
# 140       141       Chattanooga   Tennessee     Region 2           New
# 141       142             Tempe     Arizona     Region 2           New
# 142       143            Joliet    Illinois     Region 1           New
# 143       144  Rancho Cucamonga  California     Region 2           New
# 144       145          Glendale  California     Region 2           New
# 145       146          Paterson  New Jersey     Region 1           New
# 146       147       Brownsville       Texas     Region 2           New
# 147       148          Rockford    Illinois     Region 1           New
# 148       149   College Station       Texas     Region 2           New
# 149       150     Thousand Oaks  California     Region 2           New
#
#      Marketing Spend  Revenue
# 140             3587    55357
# 141             2911    48954
# 142             3279    48315
# 143             2945    52366
# 144             2363    49376
# ...

# %%
df[df['New Expansion'] == 'Old']
# Out:
#      Store ID           City         State Sales Region New Expansion  \
# 0           1         Peoria       Arizona     Region 2           Old
# 1           2        Midland         Texas     Region 2           Old
# 2           3        Spokane    Washington     Region 2           Old
# 3           4         Denton         Texas     Region 2           Old
# 4           5  Overland Park        Kansas     Region 2           Old
# ..        ...            ...           ...          ...           ...
# 135       136      San Mateo    California     Region 2           Old
# 136       137         Warren      Michigan     Region 1           Old
# 137       138        Norwalk    California     Region 2           Old
# 138       139      Lafayette     Louisiana     Region 1           Old
# 139       140     Providence  Rhode Island     Region 1           Old
#
#      Marketing Spend  Revenue
# 0               2601    48610
# 1               2727    45689
# 2               2768    49554
# ...

# %%
df[df['New Expansion'] == 'Old'].groupby('City').max()['Revenue'].nlargest(10)
# Out:
# City
# Little Rock       68828
# Grand Rapids      65475
# Rochester         64906
# Oxnard            64302
# Fontana           63027
# Providence        62337
# Birmingham        60338
# Overland Park     59887
# San Bernardino    59870
# Worcester         59840
# Name: Revenue, dtype: int64

# %%
df[df['New Expansion'] == 'Old'].groupby(['City','New Expansion']).max()['Revenue'].nlargest(10)
# Out:
# City            New Expansion
# Little Rock     Old              68828
# Grand Rapids    Old              65475
# Rochester       Old              64906
# Oxnard          Old              64302
# Fontana         Old              63027
# Providence      Old              62337
# Birmingham      Old              60338
# Overland Park   Old              59887
# San Bernardino  Old              59870
# Worcester       Old              59840
# Name: Revenue, dtype: int64

# %%
df['Count'] = round((df['Revenue']/ df['Marketing Spend']) * 100, 2)
df['Count']
# Out:
# 0      1868.90
# 1      1675.43
# 2      1790.25
# 3      1387.60
# 4      2087.38
#         ...
# 145    1537.23
# 146    1718.31
# 147    1638.10
# 148     750.07
# 149    1651.21
# Name: Count, Length: 150, dtype: float64

# %%
df
# Out:
#      Store ID             City       State Sales Region New Expansion  \
# 0           1           Peoria     Arizona     Region 2           Old
# 1           2          Midland       Texas     Region 2           Old
# 2           3          Spokane  Washington     Region 2           Old
# 3           4           Denton       Texas     Region 2           Old
# 4           5    Overland Park      Kansas     Region 2           Old
# ..        ...              ...         ...          ...           ...
# 145       146         Paterson  New Jersey     Region 1           New
# 146       147      Brownsville       Texas     Region 2           New
# 147       148         Rockford    Illinois     Region 1           New
# 148       149  College Station       Texas     Region 2           New
# 149       150    Thousand Oaks  California     Region 2           New
#
#      Marketing Spend  Revenue    Count
# 0               2601    48610  1868.90
# 1               2727    45689  1675.43
# ...

# %%
df['Profit'] = df['Revenue'] - df['Marketing Spend']
df['Profit']
# Out:
# 0      46009
# 1      42962
# 2      46786
# 3      35525
# 4      57018
#        ...
# 145    32352
# 146    59473
# 147    40729
# 148    19463
# 149    37710
# Name: Profit, Length: 150, dtype: int64

# %%
df['ROMS'] = round((df['Profit']/df['Marketing Spend'])*100,2)
df
# Out:
#      Store ID             City       State Sales Region New Expansion  \
# 0           1           Peoria     Arizona     Region 2           Old
# 1           2          Midland       Texas     Region 2           Old
# 2           3          Spokane  Washington     Region 2           Old
# 3           4           Denton       Texas     Region 2           Old
# 4           5    Overland Park      Kansas     Region 2           Old
# ..        ...              ...         ...          ...           ...
# 145       146         Paterson  New Jersey     Region 1           New
# 146       147      Brownsville       Texas     Region 2           New
# 147       148         Rockford    Illinois     Region 1           New
# 148       149  College Station       Texas     Region 2           New
# 149       150    Thousand Oaks  California     Region 2           New
#
#      Marketing Spend  Revenue    Count  Profit     ROMS
# 0               2601    48610  1868.90   46009  1768.90
# ...

# %%
df.to_csv('startup-expansion-md.csv')
